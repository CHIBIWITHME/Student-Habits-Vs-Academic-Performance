# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS ON STUDENTS HABITS VERSES ACADEMIC PERFORMANCE
#
# ---

# %% [markdown]
# Load and Clean Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data

df = pd.read_csv("student_habits_performance.csv")

df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
print("Dataset Shape:", df.shape)
# Out:
# Dataset Shape: (1000, 16)

# %%
print("\nCOLUMN DATA TYPES:")
print(df.dtypes)
# Out:
# COLUMN DATA TYPES:
# student_id                        object
# age                                int64
# gender                            object
# study_hours_per_day              float64
# social_media_hours               float64
# netflix_hours                    float64
# part_time_job                     object
# attendance_percentage            float64
# sleep_hours                      float64
# diet_quality                      object
# exercise_frequency                 int64
# parental_education_level          object
# internet_quality                  object
# mental_health_rating               int64
# extracurricular_participation     object
# exam_score                       float64
# dtype: object

# %%
print("\nMissing Values:")
print(df.isnull().sum)
# Out:
# Missing Values:
# <bound method DataFrame.sum of      student_id    age  gender  study_hours_per_day  social_media_hours  \
# 0         False  False   False                False               False
# 1         False  False   False                False               False
# 2         False  False   False                False               False
# 3         False  False   False                False               False
# 4         False  False   False                False               False
# ..          ...    ...     ...                  ...                 ...
# 995       False  False   False                False               False
# 996       False  False   False                False               False
# 997       False  False   False                False               False
# 998       False  False   False                False               False
# 999       False  False   False                False               False
#
# ...

# %%
print(df.describe())  # For the numerical data
# Out:
#              age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  1000.0000           1000.00000         1000.000000    1000.000000
# mean     20.4980              3.55010            2.505500       1.819700
# std       2.3081              1.46889            1.172422       1.075118
# min      17.0000              0.00000            0.000000       0.000000
# 25%      18.7500              2.60000            1.700000       1.000000
# 50%      20.0000              3.50000            2.500000       1.800000
# 75%      23.0000              4.50000            3.300000       2.525000
# max      24.0000              8.30000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count            1000.000000  1000.000000         1000.000000
# mean               84.131700     6.470100            3.042000
# std                 9.399246     1.226377            2.025423
# ...

# %%
print(df.describe(include='object')) # for the categorical data
# Out:
#        student_id  gender part_time_job diet_quality parental_education_level  \
# count        1000    1000          1000         1000                      909
# unique       1000       3             2            3                        3
# top         S1000  Female            No         Fair              High School
# freq            1     481           785          437                      392
#
#        internet_quality extracurricular_participation
# count              1000                          1000
# unique                3                             2
# top                Good                            No
# freq                447                           682

# %%
df.nunique()
# Out:
# student_id                       1000
# age                                 8
# gender                              3
# study_hours_per_day                78
# social_media_hours                 60
# netflix_hours                      51
# part_time_job                       2
# attendance_percentage             320
# sleep_hours                        68
# diet_quality                        3
# exercise_frequency                  7
# parental_education_level            3
# internet_quality                    3
# mental_health_rating               10
# extracurricular_participation       2
# exam_score                        480
# dtype: int64

# %%
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# Distribution of exam_score

# %%
sns.histplot(df['exam_score'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of Exam Scores')
plt.xlabel('Exam Score')
plt.ylabel('Number of Students')
plt.show()

# %% [markdown]
# Most students scored between 60 and 80 with a few low performers.

# %% [markdown]
# STUDY HOURS PER DAY

# %%
sns.histplot(df['study_hours_per_day'], kde=True, color='green')
plt.title('Daily Study Hours Distribution')
plt.xlabel('Study Hours per Day')
plt.ylabel('Number of Students')
plt.show()

# %% [markdown]
# Most students study between 2 and 4 hours/day. Few exceed 6 hours, and some barely study at all.

# %% [markdown]
# SOCIAL MEDIA HOURS

# %%
sns.histplot(df['social_media_hours'], kde=True, color='purple')
plt.title('Daily Social Media Usage')
plt.xlabel('Social Media Hours per Day')
plt.ylabel('Number of Students')
plt.show()

# %% [markdown]
# Majority spend 2–3 hours/day on social media. A few outliers use 6+ hours, this possibly will impact academic record.

# %% [markdown]
# NETFLIX HOURS

# %%
sns.histplot(df['netflix_hours'], kde=True, color='orange')
plt.title('Daily Netflix Watching Time')
plt.xlabel('Netflix Hours per Day')
plt.ylabel('Number of Students')
plt.show()

# %% [markdown]
# Average Netflix time is 1.5–2 hours/day.

# %% [markdown]
# SLEEP HOURS

# %%
sns.histplot(df['sleep_hours'], kde=True, color='teal')
plt.title('Distribution of Sleep Hours')
plt.xlabel('Sleep Hours per Night')
plt.ylabel('Number of Students')
plt.show()

# %% [markdown]
#  Insight:
# Most students sleep 6–7 hours. Some sleep less than 5 hours, which may impact health and performance.

# %% [markdown]
# WEEKLY EXERICISE

# %%
sns.histplot(df['exercise_frequency'], bins=8, kde=False, color='salmon')
plt.title('Weekly Exercise Frequency')
plt.xlabel('Days of Exercise per Week')
plt.ylabel('Number of Students')
plt.show()

# %% [markdown]
# Majority exercise 2–4 times/week. Some do not exercise at all (0 days), which could affect mental or physical well-being.

# %% [markdown]
# MENTAL HEALTH RATING

# %%
sns.histplot(df['mental_health_rating'], bins=10, kde=False, color='goldenrod')
plt.title('Self-Rated Mental Health')
plt.xlabel('Mental Health Rating (1–10)')
plt.ylabel('Number of Students')
plt.show()

# %% [markdown]
# Most students rate themselves 6–8.

# %% [markdown]
# Categorical Variable Visualization with Insights

# %% [markdown]
# GENDER

# %%
sns.countplot(data=df, x='gender', palette='pastel', hue='gender', legend=False)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Number of Students')
plt.show()

# %% [markdown]
# There's almost a balanced distribution across male and female, though female still tops.

# %% [markdown]
# PART TIME JOB

# %%
sns.countplot(data=df, x='part_time_job', palette='cool', hue='part_time_job', legend=False)
plt.title('Part-Time Job Status')
plt.xlabel('Has a Part-Time Job?')
plt.ylabel('Number of Students')
plt.show()

# %% [markdown]
# Up to 200 students have part-time job. This may impact study/sleep hours and performance.

# %% [markdown]
# DIET QUALITY

# %%
sns.countplot(data=df, x='diet_quality', palette='Set2', hue='diet_quality', legend=False)
plt.title('Diet Quality of Students')
plt.xlabel('Diet Quality')
plt.ylabel('Number of Students')
plt.show()

# %% [markdown]
# A high number of students report Fair Diet Quality. Many also reported Poor Diet Quality. This could affect sleep or mental health ratings.

# %% [markdown]
# INTERNET QUALITY

# %%
sns.countplot(data=df, x='internet_quality', palette='Set1', hue='internet_quality', legend=False)
plt.title('Internet Quality at Home')
plt.xlabel('Internet Quality')
plt.ylabel('Number of Students')
plt.show()

# %% [markdown]
# Good/poor internet Quality could affect online study effectiveness.

# %% [markdown]
# PARENTAL EDUCATION LEVEL

# %%
sns.countplot(data=df, x='parental_education_level', palette='muted', hue='parental_education_level', legend=False)
plt.title('Parental Education Level')
plt.xlabel('Highest Education Attained')
plt.ylabel('Number of Students')
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# Students with parents having higher education may show better study habits or performance.

# %% [markdown]
# EXTRACURRICULAR PARTICIPATION

# %%
sns.countplot(data=df, x='extracurricular_participation', palette='Blues', hue='extracurricular_participation', legend=False)
plt.title('Participation in Extracurricular Activities')
plt.xlabel('Participates in Extracurriculars?')
plt.ylabel('Number of Students')
plt.show()

# %% [markdown]
# Students who participates in extracurriculars might have enhanced mental health but reduced study hours.

# %% [markdown]
# Let's consider how each factor affects Exam score

# %% [markdown]
# Boxplots: Categorical Features vs. exam_score

# %% [markdown]
# PART TIME JOB VS EXAM SCORE

# %%
sns.boxplot(data=df, x='part_time_job', y='exam_score', palette='Set2', hue='part_time_job', legend=False)
plt.title('Exam Scores by Part-Time Job Status')
plt.xlabel('Has Part-Time Job?')
plt.ylabel('Exam Score')
plt.show()

# %% [markdown]
# As expected, students with part-time jobs scored lower. Time constraints might be affecting study/sleep.

# %% [markdown]
# GENDER VS EXAM SCORE

# %%
sns.boxplot(data=df, x='gender', y='exam_score', palette='pastel', hue='gender', legend=False)
plt.title('Exam Scores by Gender')
plt.xlabel('Gender')
plt.ylabel('Exam Score')
plt.show()

# %% [markdown]
# Females slightly perform better than males.

# %% [markdown]
# DIET QUALITY VS EXAM SCORE

# %%
sns.boxplot(data=df, x='diet_quality', y='exam_score', palette='coolwarm', hue='diet_quality', legend=False)
plt.title('Exam Scores by Diet Quality')
plt.xlabel('Diet Quality')
plt.ylabel('Exam Score')
plt.show()

# %% [markdown]
# A better diet might reflect better focus and energy levels.

# %% [markdown]
# EXTRACURRICULAR PARTICIPATION VS EXAM SCORE

# %%
sns.boxplot(data=df, x='extracurricular_participation', y='exam_score', palette='Blues', hue='extracurricular_participation', legend=False)
plt.title('Exam Scores vs. Extracurricular Participation')
plt.xlabel('Participates in Extracurriculars?')
plt.ylabel('Exam Score')
plt.show()

# %% [markdown]
# Seems students who participates in extracurriculars found a way to balance study time. Balance is key.

# %% [markdown]
# SCATTERPLOTS: NUMERIC DATA VS EXAM SCORE

# %% [markdown]
# STUDY HOURS PER DAY VS EXAM SCORE

# %%
sns.scatterplot(data=df, x='study_hours_per_day', y='exam_score', hue='gender', palette='deep')
plt.title('Study Hours vs. Exam Score')
plt.xlabel('Study Hours Per Day')
plt.ylabel('Exam Score')
plt.show()

# %% [markdown]
# There's a clear upward trend which shows that more study time tends to help boost performance.

# %% [markdown]
# SLEEP HOURS VS EXAM SCORE

# %%
sns.scatterplot(data=df, x='sleep_hours', y='exam_score', color='purple', hue='sleep_hours', legend=False)
plt.title('Sleep Hours vs. Exam Score')
plt.xlabel('Sleep Hours Per Night')
plt.ylabel('Exam Score')
plt.show()

# %% [markdown]
# Moderate sleep (6–8 hours) might correlate with better scores. Very low sleep likely shows poor outcomes.

# %% [markdown]
# SOCIAL MEDIA HOURS VS EXAM SCORE

# %%
sns.scatterplot(data=df, x='social_media_hours', y='exam_score', color='orange', hue='social_media_hours', legend=False)
plt.title('Social Media Usage vs. Exam Score')
plt.xlabel('Social Media Hours Per Day')
plt.ylabel('Exam Score')
plt.show()

# %% [markdown]
# As expected, higher social media use may relate to lower scores.

# %% [markdown]
# CORRELATION HEATMAP (NUMERICAL FEATURES)

# %%
# Select only numeric columns
numeric_cols = df.select_dtypes(include='number')

# Correlation matrix
corr_matrix = numeric_cols.corr()

# Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Study hours per day strongly correlates with exam score. Others are mental health rating, exercise frequency, sleep hours, and attendance percentage which are all positive correlations to exam score.

# %% [markdown]
# ## Insights Summary from EDA & Bivariate Analysis
#
# ---
#
# ### Performance Overview
# - Most students scored between **60–80**.
# - A few students scored above 90 (high performers); some scored below 50 (struggling).
#
# ---
#
# ### Key Numerical Habits
# - **Study Hours per Day**: A clear **positive correlation** with exam scores. Students studying **3–5 hours/day** tend to perform better.
# - **Sleep Hours**: Students who sleep **6 to 8 hours/night** perform better. Poor sleep (<5 hours) is associated with lower scores.
# - **Social Media Hours**: **Negative trend**. Students spending **more than 3 hours/day** on social media generally score lower.
# - **Netflix Hours**: Similar to social media — excessive time correlates with slightly lower scores.
# - **Attendance Percentage**: Strong positive correlation — higher attendance typically results in higher exam scores.
# - **Exercise Frequency**: Students exercising **2–4 times/week** may have better mental health, indirectly supporting academic performance.
#
# ---
#
# ### Key Categorical Features
# - **Part-Time Job**: Students with part-time jobs show a **slightly lower median score**, possibly due to reduced time for study/sleep.
# - **Diet Quality**: Students with **Good or Excellent diet quality** tend to score higher than those with poor diets.
# - **Internet Quality**: Students with **Good internet** generally score better, suggesting smoother access to study materials.
# - **Parental Education Level**: Students whose parents have a **Bachelor’s or higher** tend to perform better.
# - **Extracurricular Participation**: Mixed results — may benefit mental health but can also reduce study time. Balance is key.
#
# ---
#
# ### Mental Health
# - Students rating their mental health **6 or above (on a 10-point scale)** tend to score better.
# - Poor mental health is linked to **lower sleep**, **higher screen time**, and **no exercise**.
#
# ---
#
# ### Top Predictors of Exam Score (based on visual & correlation analysis)
# - `study_hours_per_day` (**strong positive**)
# - `mental_health_rating` (**moderate positive**)
# - `exercise_frequency` (**moderate positive**)
# - `attendance_percentage` (**moderate positive**)
# - `sleep_hours` (**moderate positive**)
# - `social_media_hours` (**weak negative**)
#
# ---
#
# > These insights can guide recommendations for improving student performance through healthier habits and better time management.

# %% [markdown]
# ## Data-Driven Recommendations to Improve Student Performance
#
# Based on the data analysis and observed trends, here are actionable recommendations to help students improve their academic performance:
#
# ---
#
# ### 1. Optimize Study Habits
# - Encourage students to **study at least 3–5 hours/day** for optimal results.
# - Emphasize **consistency over cramming** — regular study hours correlate with higher exam scores.
#
# ---
#
# ### 2. Prioritize Healthy Sleep
# - Promote **6.5 to 8 hours of sleep** per night.
# - Highlight that inadequate sleep (<5 hours) is associated with **significantly lower performance**.
#
# ---
#
# ### 3. Manage Screen Time Wisely
# - Students spending **more than 3 hours/day** on social media or streaming platforms (e.g., Netflix) tend to underperform.
# - Schools can offer **digital well-being workshops** or introduce app usage tracking tools.
#
# ---
#
# ### 4. Improve Class Attendance
# - Reinforce policies that encourage students to maintain **80%+ attendance**.
# - Consider implementing **attendance incentives** or feedback systems.
#
# ---
#
# ### 5. Promote Better Diet and Lifestyle
# - Students reporting **Good/Excellent diet quality** showed higher scores.
# - Schools can run **nutrition awareness programs** and promote **on-campus healthy food options**.
#
# ---
#
# ### 6. Support Mental Health
# - A higher mental health rating correlates with better scores.
# - Recommendations:
#   - Increase access to **counselors and mental health resources**.
#   - Encourage **moderate exercise** (2–4 times/week).
#   - Host **stress-relief workshops** during exam season.
#
# ---
#
# ### 7. Improve Access to Internet & Learning Tools
# - Students with **good internet quality** perform better — likely due to improved access to online materials.
# - Suggest partnerships with ISPs or tech organizations to provide **low-cost access and devices**.
#
# ---
#
# ### 8. Parental Engagement
# - Students with more educated parents tend to score better.
# - Schools could:
#   - Organize **parental guidance sessions** on supporting children's academic habits.
#   - Share **monthly academic summaries** with guardians.
#
# ---
#
# > These targeted interventions can help schools and students create a healthier, more effective learning environment — improving both academic outcomes and overall well-being.
